# %% [markdown]
# ### Import libaries for data preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read files

# %%
movies = pd.read_csv("movies.csv")
ratings = pd.read_csv("ratings.csv")

# %%
movies.head(5)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head(5)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# ### Join tables

# %%
movie_ratings = pd.merge(ratings, movies, on="movieId")
movie_ratings.head(5)
# Out:
#    userId  movieId  rating   timestamp             title  \
# 0       1        1     4.0   964982703  Toy Story (1995)
# 1       5        1     4.0   847434962  Toy Story (1995)
# 2       7        1     4.5  1106635946  Toy Story (1995)
# 3      15        1     2.5  1510577970  Toy Story (1995)
# 4      17        1     4.5  1305696483  Toy Story (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1  Adventure|Animation|Children|Comedy|Fantasy
# 2  Adventure|Animation|Children|Comedy|Fantasy
# 3  Adventure|Animation|Children|Comedy|Fantasy
# 4  Adventure|Animation|Children|Comedy|Fantasy

# %% [markdown]
# ### Add rating class

# %%
rating_classes = ['bad', 'mediocre', 'good']

def assign_rating_class(x):
    if x.rating < 3:
        return 'bad'
    elif x.rating < 4.5:
        return 'mediocre'
    return 'good'

movie_ratings["rating_class"] = movie_ratings.apply(lambda x: assign_rating_class(x), axis=1)
movie_ratings.head(5)
# Out:
#    userId  movieId  rating   timestamp             title  \
# 0       1        1     4.0   964982703  Toy Story (1995)
# 1       5        1     4.0   847434962  Toy Story (1995)
# 2       7        1     4.5  1106635946  Toy Story (1995)
# 3      15        1     2.5  1510577970  Toy Story (1995)
# 4      17        1     4.5  1305696483  Toy Story (1995)
#
#                                         genres rating_class
# 0  Adventure|Animation|Children|Comedy|Fantasy     mediocre
# 1  Adventure|Animation|Children|Comedy|Fantasy     mediocre
# 2  Adventure|Animation|Children|Comedy|Fantasy         good
# 3  Adventure|Animation|Children|Comedy|Fantasy          bad
# 4  Adventure|Animation|Children|Comedy|Fantasy         good

# %%
bins = np.arange(0.5, 6, 0.5) - 0.25
movie_ratings.rating.plot(kind='hist', edgecolor="black", bins=bins)
plt.xticks(np.arange(0.5, 6, 0.5))
plt.xlim([0, 5.5])
# Out:
# (0.0, 5.5)

# %% [markdown]
# ### Take year intervals

# %%
import re

# extract years
movie_years = movies.title.str.strip().apply(lambda x: re.findall(r'\(\d+\)$', x)).str[0].str[1:-1]
# remove titles with no year and display their count
movie_mask = [0 if x == x else 1 for x in movie_years]
removed_films = sum(movie_mask)
movie_years = [int(movie_years[x]) for x in range(len(movie_years)) if movie_mask[x] == 0]

print(f'Sum of excluded movies: {removed_films}')
print(f"Min year: {min(movie_years)}")
print(f"Max year: {max(movie_years)}")

plt.hist(movie_years, bins=40, edgecolor="black")
plt.show()
# Out:
# Sum of excluded movies: 13
# Min year: 1902
# Max year: 2018

# %%
# year_intervals_5 = [f"[{str(x)},{str(x+5)}]" for x in range(1920, 2020, 5)]
year_intervals_10 = [f"({str(x)},{str(x+10)}]" for x in range(1920, 2020, 10)]
year_intervals_10
# Out:
# ['(1920,1930]',
#  '(1930,1940]',
#  '(1940,1950]',
#  '(1950,1960]',
#  '(1960,1970]',
#  '(1970,1980]',
#  '(1980,1990]',
#  '(1990,2000]',
#  '(2000,2010]',
#  '(2010,2020]']

# %% [markdown]
# ### Create table of users to film rating and year interval

# %%
year_ratings = [str(year) + "|" + rating for year in year_intervals_10 for rating in rating_classes]
year_ratings[:5]
# Out:
# ['(1920,1930]|bad',
#  '(1920,1930]|mediocre',
#  '(1920,1930]|good',
#  '(1930,1940]|bad',
#  '(1930,1940]|mediocre']

# %% [markdown]
# ### Binarize the data

# %%
def get_year_interval(year):
    # if nan
    try:
        year = int(year)
    except ValueError:
        return ""
    
    for x in range(1920, 2020, 10):
        if (year <= x+10 and year > x):
            return f"({str(x)},{str(x+10)}]"
    
    # if not a year in the interval
    return ""

unique_users = ratings.userId.unique()

binary_df = np.zeros((len(unique_users), len(year_ratings)), dtype=np.int8)

for user_id in unique_users:
    user_ratings = movie_ratings.loc[movie_ratings['userId'] == user_id]
    user_movie_years = user_ratings.title.str.strip().apply(lambda x: re.findall(r'\(\d+\)$', x)).str[0].str[1:-1]
    user_movie_ratings = user_ratings.rating_class
    user_movie_year_ratings = set([get_year_interval(year) + "|" + r_class for year, r_class in zip(user_movie_years, user_movie_ratings)])
    binary_df[user_id-1] = [1 if x in user_movie_year_ratings else 0 for x in year_ratings]

# %%
binary_df = pd.DataFrame(binary_df)
binary_df.columns = year_ratings
binary_df = binary_df.astype(bool)
binary_df_users = binary_df.copy()
binary_df_users.insert(0, column="userId", value=unique_users)
binary_df_users.tail(5)
# Out:
#      userId  (1920,1930]|bad  (1920,1930]|mediocre  (1920,1930]|good  \
# 605     606            False                  True              True
# 606     607            False                 False             False
# 607     608            False                 False             False
# 608     609            False                 False             False
# 609     610            False                 False             False
#
#      (1930,1940]|bad  (1930,1940]|mediocre  (1930,1940]|good  (1940,1950]|bad  \
# 605            False                  True              True            False
# 606             True                  True              True            False
# 607             True                  True             False             True
# 608            False                 False             False            False
# 609            False                  True             False            False
#
#      (1940,1950]|mediocre  (1940,1950]|good  ...  (1980,1990]|good  \
# 605                  True              True  ...              True
# 606                 False              True  ...              True
# 607                  True             False  ...              True
# 608                 False             False  ...             False
# 609                  True             False  ...              True
#
#      (1990,2000]|bad  (1990,2000]|mediocre  (1990,2000]|good  (2000,2010]|bad  \
# 605             True                  True              True             True
# 606             True                  True              True            False
# 607             True                  True              True             True
# 608            False                  True             False            False
# 609             True                  True              True             True
#
#      (2000,2010]|mediocre  (2000,2010]|good  (2010,2020]|bad  \
# 605                  True              True             True
# 606                  True             False            False
# 607                  True              True            False
# 608                 False             False            False
# 609                  True              True             True
#
#      (2010,2020]|mediocre  (2010,2020]|good
# 605                  True              True
# 606                 False             False
# 607                 False             False
# 608                 False             False
# 609                  True              True
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Run apriori algorithm

# %%
from mlxtend.frequent_patterns import apriori

# %%
frequent_itemsets = apriori(binary_df, min_support=0.6, use_colnames=True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.639344                             ((1970,1980]|mediocre)
# 1   0.852459                             ((1980,1990]|mediocre)
# 2   0.662295                                 ((1980,1990]|good)
# 3   0.798361                                  ((1990,2000]|bad)
# 4   0.980328                             ((1990,2000]|mediocre)
# 5   0.934426                                 ((1990,2000]|good)
# 6   0.624590                             ((2000,2010]|mediocre)
# 7   0.636066       ((1990,2000]|mediocre, (1970,1980]|mediocre)
# 8   0.606557           ((1990,2000]|good, (1970,1980]|mediocre)
# 9   0.604918           ((1980,1990]|good, (1980,1990]|mediocre)
# 10  0.709836            ((1990,2000]|bad, (1980,1990]|mediocre)
# 11  0.845902       ((1990,2000]|mediocre, (1980,1990]|mediocre)
# 12  0.801639           ((1990,2000]|good, (1980,1990]|mediocre)
# 13  0.655738           ((1990,2000]|mediocre, (1980,1990]|good)
# 14  0.650820               ((1990,2000]|good, (1980,1990]|good)
# 15  0.788525            ((1990,2000]|mediocre, (1990,2000]|bad)
# 16  0.752459                ((1990,2000]|good, (1990,2000]|bad)
# 17  0.921311           ((1990,2000]|good, (1990,2000]|mediocre)
# 18  0.619672       ((1990,2000]|mediocre, (2000,2010]|mediocre)
# 19  0.603279  ((1990,2000]|good, (1990,2000]|mediocre, (1970...
# 20  0.601639  ((1990,2000]|mediocre, (1980,1990]|good, (1980...
# 21  0.704918  ((1990,2000]|mediocre, (1990,2000]|bad, (1980,...
# 22  0.673770  ((1990,2000]|good, (1990,2000]|bad, (1980,1990...
# 23  0.796721  ((1990,2000]|good, (1990,2000]|mediocre, (1980...
# 24  0.645902  ((1990,2000]|good, (1990,2000]|mediocre, (1980...
# 25  0.747541  ((1990,2000]|good, (1990,2000]|mediocre, (1990...
# 26  0.670492  ((1990,2000]|good, (1990,2000]|mediocre, (1990...

# %% [markdown]
# ### Find association rules

# %%
from mlxtend.frequent_patterns import association_rules

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.8)
rules
# Out:
#                                           antecedents  \
# 0                              ((1970,1980]|mediocre)
# 1                              ((1970,1980]|mediocre)
# 2                                  ((1980,1990]|good)
# 3                                   ((1990,2000]|bad)
# 4                              ((1980,1990]|mediocre)
# 5                              ((1990,2000]|mediocre)
# 6                              ((1980,1990]|mediocre)
# 7                                  ((1990,2000]|good)
# 8                              ((1980,1990]|mediocre)
# 9                                  ((1980,1990]|good)
# 10                                 ((1980,1990]|good)
# 11                             ((1990,2000]|mediocre)
# 12                                  ((1990,2000]|bad)
# 13                                 ((1990,2000]|good)
# 14                                  ((1990,2000]|bad)
# 15                                 ((1990,2000]|good)
# 16                             ((1990,2000]|mediocre)
# 17                             ((2000,2010]|mediocre)
# 18           ((1990,2000]|good, (1970,1980]|mediocre)
# 19       ((1990,2000]|mediocre, (1970,1980]|mediocre)
# 20                             ((1970,1980]|mediocre)
# 21           ((1990,2000]|mediocre, (1980,1990]|good)
# 22           ((1980,1990]|good, (1980,1990]|mediocre)
# 23                                 ((1980,1990]|good)
# 24            ((1990,2000]|mediocre, (1990,2000]|bad)
# 25       ((1990,2000]|mediocre, (1980,1990]|mediocre)
# 26            ((1990,2000]|bad, (1980,1990]|mediocre)
# 27                                  ((1990,2000]|bad)
# 28                             ((1980,1990]|mediocre)
# 29                ((1990,2000]|good, (1990,2000]|bad)
# 30           ((1990,2000]|good, (1980,1990]|mediocre)
# 31            ((1990,2000]|bad, (1980,1990]|mediocre)
# 32                                  ((1990,2000]|bad)
# 33           ((1990,2000]|good, (1990,2000]|mediocre)
# 34           ((1990,2000]|good, (1980,1990]|mediocre)
# 35       ((1990,2000]|mediocre, (1980,1990]|mediocre)
# 36                                 ((1990,2000]|good)
# 37                             ((1990,2000]|mediocre)
# 38                             ((1980,1990]|mediocre)
# 39               ((1990,2000]|good, (1980,1990]|good)
# 40           ((1990,2000]|mediocre, (1980,1990]|good)
# 41                                 ((1980,1990]|good)
# 42           ((1990,2000]|good, (1990,2000]|mediocre)
# 43                ((1990,2000]|good, (1990,2000]|bad)
# 44            ((1990,2000]|mediocre, (1990,2000]|bad)
# 45                                 ((1990,2000]|good)
# 46                                  ((1990,2000]|bad)
# 47  ((1990,2000]|good, (1990,2000]|bad, (1990,2000...
# 48  ((1990,2000]|good, (1980,1990]|mediocre, (1990...
# 49  ((1990,2000]|good, (1990,2000]|bad, (1980,1990...
# 50  ((1990,2000]|mediocre, (1990,2000]|bad, (1980,...
# 51                ((1990,2000]|good, (1990,2000]|bad)
# 52           ((1990,2000]|good, (1980,1990]|mediocre)
# 53            ((1990,2000]|mediocre, (1990,2000]|bad)
# 54            ((1990,2000]|bad, (1980,1990]|mediocre)
# 55                                  ((1990,2000]|bad)
#
#                                           consequents  antecedent support  \
# 0                              ((1990,2000]|mediocre)            0.639344
# 1                                  ((1990,2000]|good)            0.639344
# 2                              ((1980,1990]|mediocre)            0.662295
# 3                              ((1980,1990]|mediocre)            0.798361
# 4                                   ((1990,2000]|bad)            0.852459
# 5                              ((1980,1990]|mediocre)            0.980328
# 6                              ((1990,2000]|mediocre)            0.852459
# 7                              ((1980,1990]|mediocre)            0.934426
# 8                                  ((1990,2000]|good)            0.852459
# 9                              ((1990,2000]|mediocre)            0.662295
# 10                                 ((1990,2000]|good)            0.662295
# 11                                  ((1990,2000]|bad)            0.980328
# 12                             ((1990,2000]|mediocre)            0.798361
# 13                                  ((1990,2000]|bad)            0.934426
# 14                                 ((1990,2000]|good)            0.798361
# 15                             ((1990,2000]|mediocre)            0.934426
# 16                                 ((1990,2000]|good)            0.980328
# 17                             ((1990,2000]|mediocre)            0.624590
# 18                             ((1990,2000]|mediocre)            0.606557
# 19                                 ((1990,2000]|good)            0.636066
# 20           ((1990,2000]|good, (1990,2000]|mediocre)            0.639344
# 21                             ((1980,1990]|mediocre)            0.655738
# 22                             ((1990,2000]|mediocre)            0.604918
# 23       ((1990,2000]|mediocre, (1980,1990]|mediocre)            0.662295
# 24                             ((1980,1990]|mediocre)            0.788525
# 25                                  ((1990,2000]|bad)            0.845902
# 26                             ((1990,2000]|mediocre)            0.709836
# 27       ((1990,2000]|mediocre, (1980,1990]|mediocre)            0.798361
# 28            ((1990,2000]|mediocre, (1990,2000]|bad)            0.852459
# 29                             ((1980,1990]|mediocre)            0.752459
# 30                                  ((1990,2000]|bad)            0.801639
# 31                                 ((1990,2000]|good)            0.709836
# 32           ((1990,2000]|good, (1980,1990]|mediocre)            0.798361
# 33                             ((1980,1990]|mediocre)            0.921311
# 34                             ((1990,2000]|mediocre)            0.801639
# 35                                 ((1990,2000]|good)            0.845902
# 36       ((1990,2000]|mediocre, (1980,1990]|mediocre)            0.934426
# 37           ((1990,2000]|good, (1980,1990]|mediocre)            0.980328
# 38           ((1990,2000]|good, (1990,2000]|mediocre)            0.852459
# 39                             ((1990,2000]|mediocre)            0.650820
# 40                                 ((1990,2000]|good)            0.655738
# 41           ((1990,2000]|good, (1990,2000]|mediocre)            0.662295
# 42                                  ((1990,2000]|bad)            0.921311
# 43                             ((1990,2000]|mediocre)            0.752459
# 44                                 ((1990,2000]|good)            0.788525
# 45            ((1990,2000]|mediocre, (1990,2000]|bad)            0.934426
# 46           ((1990,2000]|good, (1990,2000]|mediocre)            0.798361
# 47                             ((1980,1990]|mediocre)            0.747541
# 48                                  ((1990,2000]|bad)            0.796721
# 49                             ((1990,2000]|mediocre)            0.673770
# 50                                 ((1990,2000]|good)            0.704918
# 51       ((1990,2000]|mediocre, (1980,1990]|mediocre)            0.752459
# 52            ((1990,2000]|mediocre, (1990,2000]|bad)            0.801639
# 53           ((1990,2000]|good, (1980,1990]|mediocre)            0.788525
# 54           ((1990,2000]|good, (1990,2000]|mediocre)            0.709836
# 55  ((1990,2000]|good, (1980,1990]|mediocre, (1990...            0.798361
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.980328  0.636066    0.994872  1.014836  0.009299    3.836066
# 1             0.934426  0.606557    0.948718  1.015295  0.009137    1.278689
# 2             0.852459  0.604918    0.913366  1.071449  0.040339    1.703044
# 3             0.852459  0.709836    0.889117  1.043003  0.029266    1.330601
# 4             0.798361  0.709836    0.832692  1.043003  0.029266    1.205201
# 5             0.852459  0.845902    0.862876  1.012220  0.010212    1.075970
# 6             0.980328  0.845902    0.992308  1.012220  0.010212    2.557377
# 7             0.852459  0.801639    0.857895  1.006377  0.005079    1.038251
# 8             0.934426  0.801639    0.940385  1.006377  0.005079    1.099947
# 9             0.980328  0.655738    0.990099  1.009967  0.006471    1.986885
# 10            0.934426  0.650820    0.982673  1.051633  0.031954    3.784543
# 11            0.798361  0.788525    0.804348  1.007499  0.005869    1.030601
# 12            0.980328  0.788525    0.987680  1.007499  0.005869    1.596721
# 13            0.798361  0.752459    0.805263  1.008646  0.006450    1.035445
# 14            0.934426  0.752459    0.942505  1.008646  0.006450    1.140515
# 15            0.980328  0.921311    0.985965  1.005750  0.005267    1.401639
# 16            0.934426  0.921311    0.939799  1.005750  0.005267    1.089253
# 17            0.980328  0.619672    0.992126  1.012035  0.007369    2.498361
# 18            0.980328  0.603279    0.994595  1.014553  0.008654    3.639344
# 19            0.934426  0.603279    0.948454  1.015012  0.008922    1.272131
# 20            0.921311  0.603279    0.943590  1.024181  0.014243    1.394933
# 21            0.852459  0.601639    0.917500  1.076298  0.042650    1.788376
# 22            0.980328  0.601639    0.994580  1.014538  0.008621    3.629508
# 23            0.845902  0.601639    0.908416  1.073902  0.041403    1.682588
# 24            0.852459  0.704918    0.893971  1.048697  0.032733    1.391514
# 25            0.798361  0.704918    0.833333  1.043806  0.029583    1.209836
# 26            0.980328  0.704918    0.993072  1.012999  0.009046    2.839344
# 27            0.845902  0.704918    0.882957  1.043806  0.029583    1.316595
# 28            0.788525  0.704918    0.826923  1.048697  0.032733    1.221858
# 29            0.852459  0.673770    0.895425  1.050402  0.032330    1.410861
# 30            0.798361  0.673770    0.840491  1.052771  0.033773    1.264124
# 31            0.934426  0.673770    0.949192  1.015802  0.010481    1.290611
# 32            0.801639  0.673770    0.843943  1.052771  0.033773    1.271074
# 33            0.852459  0.796721    0.864769  1.014440  0.011341    1.091027
# 34            0.980328  0.796721    0.993865  1.013809  0.010852    3.206557
# 35            0.934426  0.796721    0.941860  1.007956  0.006289    1.127869
# 36            0.845902  0.796721    0.852632  1.007956  0.006289    1.045667
# 37            0.801639  0.796721    0.812709  1.013809  0.010852    1.059104
# 38            0.921311  0.796721    0.934615  1.014440  0.011341    1.203472
# 39            0.980328  0.645902    0.992443  1.012359  0.007885    2.603279
# 40            0.934426  0.645902    0.985000  1.054123  0.033163    4.371585
# 41            0.921311  0.645902    0.975248  1.058543  0.035722    3.179016
# 42            0.798361  0.747541    0.811388  1.016317  0.012002    1.069069
# 43            0.980328  0.747541    0.993464  1.013400  0.009884    3.009836
# 44            0.934426  0.747541    0.948025  1.014553  0.010723    1.261639
# 45            0.788525  0.747541    0.800000  1.014553  0.010723    1.057377
# 46            0.921311  0.747541    0.936345  1.016317  0.012002    1.236171
# 47            0.852459  0.670492    0.896930  1.052168  0.033244    1.431461
# 48            0.798361  0.670492    0.841564  1.054115  0.034421    1.272685
# 49            0.980328  0.670492    0.995134  1.015103  0.009976    4.042623
# 50            0.934426  0.670492    0.951163  1.017911  0.011798    1.342701
# 51            0.845902  0.670492    0.891068  1.053394  0.033985    1.414623
# 52            0.788525  0.670492    0.836401  1.060716  0.038379    1.292643
# 53            0.801639  0.670492    0.850312  1.060716  0.038379    1.325159
# 54            0.921311  0.670492    0.944573  1.025248  0.016512    1.419672
# 55            0.796721  0.670492    0.839836  1.054115  0.034421    1.269189
#
#     zhangs_metric
# 0        0.040534
# 1        0.041769
# 2        0.197464
# 3        0.204472
# 4        0.279446
# 5        0.613695
# 6        0.081826
# 7        0.096626
# 8        0.042945
# 9        0.029223
# 10       0.145387
# 11       0.378378
# 12       0.036915
# 13       0.130719
# 14       0.042510
# 15       0.087189
# 16       0.290629
# 17       0.031677
# 18       0.036458
# 19       0.040638
# 20       0.065464
# 21       0.205917
# 22       0.036270
# 23       0.203778
# 24       0.219578
# 25       0.272340
# 26       0.044225
# 27       0.208130
# 28       0.314729
# 29       0.193842
# 30       0.252700
# 31       0.053610
# 32       0.248591
# 33       0.180898
# 34       0.068666
# 35       0.051221
# 36       0.120370
# 37       0.692387
# 38       0.096479
# 39       0.034961
# 40       0.149142
# 41       0.163767
# 42       0.204039
# 43       0.053416
# 44       0.067829
# 45       0.218750
# 46       0.079625
# 47       0.196393
# 48       0.252544
# 49       0.045607
# 50       0.059631
# 51       0.204764
# 52       0.288569
# 53       0.270673
# 54       0.084870
# 55       0.254597

# %% [markdown]
# #### Write results to files

# %%
with open("frequent_itemsets.txt", "w") as fi:
    fi.write(frequent_itemsets.to_string())

# %%
with open("association_rules.txt", "w") as fr:
    fr.write(rules.to_string())
